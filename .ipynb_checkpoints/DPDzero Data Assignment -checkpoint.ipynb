# %% [markdown]
# # **Project Name**
# $\color{red}{\text{DPDzero Data Assignment}}$

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **Data Processing**
#
#     1.Importing libraries
#     2.Function for reading dataset
#     3.dataset information
#     4.Missing values,Duplicated values
#
# **Exploratory Data Analysis**
#
# **Supervised Machine learning Algorithm**
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# # **Data overview and column description**

# %% [markdown]
# **There are two dataset needed for the project**

# %% [markdown]
# ## **portfolio data**
# **This contains the details on loans given to few customers and their demographic information**

# %% [markdown]
# | Column          | Description     |
# | --------------- | --------------- |
# | Loan Number     | Loan Number given to each customer  |
# | Due Date        |  Repaying dae of loan by the customer |
# | State           |  origin of state of each customer |
# | DOB             |Date of birth of the customer   |
# | Loan Amount     | Loan amount given to each customer |

# %% [markdown]
# ## **Communication History**
# **The attempts made to reach out to these customers and the status of these calls.**

# %% [markdown]
# | Column          | Description     |
# | --------------- | --------------- |
# | Loan Number     | Loan Number given to each customer  |
# | Campaign ID     |  Campaign ID by the bank  |
# |Communication Operator Message ID  |  operator Id for each communication done in messages |
# | Call time       |Date of birth of the customer   |
# | Status    | status of the repayment |

# %% [markdown]
# # **Let's Begin**

# %% [markdown]
# ## **Knowing the Data**

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Function to load the data 
def DataLoader(path,Date=None,date_cols=None):
    """
    A function to load the datset 
    Argumet - Path(path to the data file)
    return - dataframe
    """
    try:
        dataframe = pd.read_excel(path,index_col=Date,parse_dates=date_cols)
        return dataframe
    except: # if path is incorrect or does not exist
        print("path does not find")

    finally:
        print("operation performed on the  dataset Location")

# %%
CommunicationHistory_df = DataLoader("CommunicationHistory.xlsx",date_cols=['Call time'])
# Out:
# operation performed on the  dataset Location

# %%
date_cols = ['Due Date','DOB']
portfolio_df = DataLoader("Portfolio_data.xlsx",date_cols=date_cols)
# Out:
# operation performed on the  dataset Location

# %% [markdown]
# ### Dataset First View

# %%
CommunicationHistory_df.head()
# Out:
#    Loan Number  Campaign ID Communication Operator Message ID  \
# 0  16748071234    161584404  21a1f7b1ce4d23d558e300626d5016c2
# 1  16734601234    161584404  edecb5cd796826ef8bcde2f4814f16c2
# 2      1631580    161307935  6a79ed24fa727ae9341f53a9df8816c2
# 3      1631580    161307935  ce45ac657c26d5d10e6d1eb4aacc16c2
# 4      1631580    161307935  6c864d7097f2df3eed4900ea892816c2
#
#                          Call time     Status
# 0 2022-12-02 02:59:40.973000+00:00  completed
# 1 2022-12-02 03:57:51.335000+00:00  completed
# 2 2022-12-02 04:34:26.950000+00:00  completed
# 3 2022-12-02 04:34:57.213000+00:00  completed
# 4 2022-12-02 04:36:21.594000+00:00  completed

# %%
portfolio_df.head()
# Out:
#    Loan Number   Due Date          State                  DOB  Loan Amount
# 0      1003431 2022-10-31      KARNATAKA  1987-02-09 00:00:00     240000.0
# 1      1004356 2022-10-31    MAHARASHTRA  1994-05-23 00:00:00      56000.0
# 2      1004464 2022-11-01  UTTAR PRADESH  1996-12-01 00:00:00      50000.0
# 3      1004626 2022-11-01         KERALA  1995-07-14 00:00:00      63000.0
# 4      1005011 2022-11-01    MAHARASHTRA  1994-05-30 00:00:00      50000.0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"the CommunicationHistory dataset has toltal of  {CommunicationHistory_df.shape[0]} rows and {CommunicationHistory_df.shape[1]} columns")
# Out:
# the CommunicationHistory dataset has toltal of  70607 rows and 5 columns

# %%
# Dataset Rows & Columns count
print(f"the portfolio dataset has toltal of  {portfolio_df.shape[0]} rows and {portfolio_df.shape[1]} columns")
# Out:
# the portfolio dataset has toltal of  15962 rows and 5 columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
CommunicationHistory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70607 entries, 0 to 70606
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Loan Number                        70607 non-null  int64
#  1   Campaign ID                        70607 non-null  int64
#  2   Communication Operator Message ID  70597 non-null  object
#  3   Call time                          70607 non-null  datetime64[ns, UTC]
#  4   Status                             70607 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(2), object(2)
# memory usage: 2.7+ MB

# %%
# portfolio Dataset Info
portfolio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15962 entries, 0 to 15961
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Loan Number  15962 non-null  int64
#  1   Due Date     15962 non-null  datetime64[ns]
#  2   State        15962 non-null  object
#  3   DOB          15961 non-null  object
#  4   Loan Amount  15962 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 623.6+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# CommunicationHistory Dataset Duplicate Value Count
CommunicationHistory_df.duplicated().sum()
# Out:
# 0

# %%
# portfolio Dataset Duplicate Value Count
portfolio_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count in CommunicationHistory dataset
CommunicationHistory_df.isna().sum().sort_values(ascending=False)
# Out:
# Communication Operator Message ID    10
# Loan Number                           0
# Campaign ID                           0
# Call time                             0
# Status                                0
# dtype: int64

# %%
# Missing Values/Null Values Count in portfolio dataset
portfolio_df.isna().sum().sort_values(ascending=False)
# Out:
# DOB            1
# Loan Number    0
# Due Date       0
# State          0
# Loan Amount    0
# dtype: int64

# %% [markdown]
# ### Dataset Description

# %%
CommunicationHistory_df.describe(include='all')
# Out:
#          Loan Number   Campaign ID Communication Operator Message ID  \
# count   7.060700e+04  7.060700e+04                             70597
# unique           NaN           NaN                             70597
# top              NaN           NaN  21a1f7b1ce4d23d558e300626d5016c2
# freq             NaN           NaN                                 1
# first            NaN           NaN                               NaN
# last             NaN           NaN                               NaN
# mean    2.387413e+06  1.681513e+08                               NaN
# std     1.077388e+08  2.845385e+06                               NaN
# min     8.727770e+05  1.354742e+08                               NaN
# 25%     1.635118e+06  1.654490e+08                               NaN
# 50%     1.705979e+06  1.678209e+08                               NaN
# 75%     1.778082e+06  1.707402e+08                               NaN
# max     1.674807e+10  1.735366e+08                               NaN
#
#                                Call time     Status
# count                              70607      70607
# unique                             70563          2
# top     2022-12-03 13:16:19.023000+00:00  completed
# freq                                   2      70589
# first   2022-12-02 02:59:40.973000+00:00        NaN
# last    2022-12-07 23:25:16.448000+00:00        NaN
# mean                                 NaN        NaN
# std                                  NaN        NaN
# min                                  NaN        NaN
# 25%                                  NaN        NaN
# 50%                                  NaN        NaN
# 75%                                  NaN        NaN
# max                                  NaN        NaN

# %%
portfolio_df.describe(include='all')
# Out:
#          Loan Number             Due Date        State                  DOB  \
# count   1.596200e+04                15962        15962                15961
# unique           NaN                   30           40                 6741
# top              NaN  2022-11-25 00:00:00  MAHARASHTRA  1998-01-01 00:00:00
# freq             NaN                 1080         2538                   56
# first            NaN  2022-10-31 00:00:00          NaN                  NaN
# last             NaN  2022-11-29 00:00:00          NaN                  NaN
# mean    1.689427e+06                  NaN          NaN                  NaN
# std     1.211048e+05                  NaN          NaN                  NaN
# min     8.727770e+05                  NaN          NaN                  NaN
# 25%     1.640865e+06                  NaN          NaN                  NaN
# 50%     1.714308e+06                  NaN          NaN                  NaN
# 75%     1.778172e+06                  NaN          NaN                  NaN
# max     1.881403e+06                  NaN          NaN                  NaN
#
#           Loan Amount
# count    15962.000000
# unique            NaN
# top               NaN
# freq              NaN
# first             NaN
# last              NaN
# mean      7362.359952
# std       6398.129954
# min       3000.000000
# 25%       5000.000000
# 50%       5017.000000
# 75%       7000.000000
# max     240000.000000

# %%
#print unique value in categorical value 
#since the dataset is large numerical value whose unique number are less than should be focussed

def print_values(dataframe):
    for i in dataframe.columns.tolist():
        if dataframe[i].dtype=='O':
            print(f"the categorical column {i} have {dataframe[i].nunique()} unique values ")
            if dataframe[i].nunique() <=31 :
                print(f"the unique value in the columns are {dataframe[i].unique()}")
        else:
            print(f"the  numerical column {i} have {dataframe[i].nunique()} unique values ")
            if dataframe[i].nunique() <=15:
                print(f" the unique value in the columns are{dataframe[i].unique()}")

# %%
print_values(CommunicationHistory_df)
# Out:
# the  numerical column Loan Number have 11220 unique values
# the  numerical column Campaign ID have 40 unique values
# the categorical column Communication Operator Message ID have 70597 unique values
# the  numerical column Call time have 70563 unique values
# the categorical column Status have 2 unique values
# the unique value in the columns are ['completed' 'FAILED']

# %%
print_values(portfolio_df)
# Out:
# the  numerical column Loan Number have 15962 unique values
# the  numerical column Due Date have 30 unique values
# the categorical column State have 40 unique values
# the categorical column DOB have 6741 unique values
# the  numerical column Loan Amount have 304 unique values

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# **To perform opearationon dataset we have to merge the dataset,Since both the dataset have Loan number in common we would merge the dataset on Loan number**

# %%
#create final dataset by merging the two dataframe on  Loan Number column 
final_dataset = pd.merge(CommunicationHistory_df,portfolio_df,how='left', on='Loan Number')

# %%
final_dataset.head()
# Out:
#    Loan Number  Campaign ID Communication Operator Message ID  \
# 0  16748071234    161584404  21a1f7b1ce4d23d558e300626d5016c2
# 1  16734601234    161584404  edecb5cd796826ef8bcde2f4814f16c2
# 2      1631580    161307935  6a79ed24fa727ae9341f53a9df8816c2
# 3      1631580    161307935  ce45ac657c26d5d10e6d1eb4aacc16c2
# 4      1631580    161307935  6c864d7097f2df3eed4900ea892816c2
#
#                          Call time     Status Due Date State  DOB  Loan Amount
# 0 2022-12-02 02:59:40.973000+00:00  completed      NaT   NaN  NaN          NaN
# 1 2022-12-02 03:57:51.335000+00:00  completed      NaT   NaN  NaN          NaN
# 2 2022-12-02 04:34:26.950000+00:00  completed      NaT   NaN  NaN          NaN
# 3 2022-12-02 04:34:57.213000+00:00  completed      NaT   NaN  NaN          NaN
# 4 2022-12-02 04:36:21.594000+00:00  completed      NaT   NaN  NaN          NaN

# %% [markdown]
# #### Distribution of loans across different states

# %%
#groupt the datasetby state and calculate avg loan amount across states
final_dataset.groupby("State")["Loan Amount"].mean().reset_index().sort_values("Loan Amount",ascending= False)
# Out:
#                         State   Loan Amount
# 14           HIMACHAL PRADESH  13317.750000
# 3           Arunachal Pradesh  12769.230769
# 23                Maharashtra  12190.476190
# 32                     Sikkim  11807.827586
# 12                        Goa   9924.816667
# 5                 CHATTISGARH   9267.178125
# 19                     KERALA   8270.710578
# 18                  KARNATAKA   8146.555493
# 33                 TAMIL NADU   7955.937760
# 38                WEST BENGAL   7743.899696
# 29                     PUNJAB   7709.016014
# 10                      DELHI   7646.889406
# 11                    GUJARAT   7585.664162
# 21                MAHARASHTRA   7362.929871
# 37                UTTARAKHAND   7314.757576
# 34                  TELANGANA   7213.160365
# 17                  JHARKHAND   7208.865079
# 31                  RAJASTHAN   7132.352372
# 1              ANDHRA PRADESH   7118.952555
# 13                    HARYANA   7090.189330
# 28                     ODISHA   7073.584989
# 26                    Mizoram   7000.000000
# 22             Madhya Pradesh   7000.000000
# 36              UTTAR PRADESH   6981.753107
# 30                Pondicherry   6929.682081
# 20             MADHYA PRADESH   6862.536786
# 4                       BIHAR   6819.619411
# 2                       ASSAM   6791.961842
# 6                  Chandigarh   6703.468468
# 16            JAMMU & KASHMIR   6332.377551
# 27                   Nagaland   6234.692308
# 9                 DAMAN & DIU   6189.647059
# 35                    TRIPURA   6054.064516
# 24                    Manipur   5503.462963
# 25                  Meghalaya   5223.400000
# 7                 Chattisgarh   5017.000000
# 8        DADRA & NAGAR HAVELI   5017.000000
# 15                    Haryana   5000.000000
# 0   ANDAMAN & NICOBAR ISLANDS   5000.000000

# %%
#groupt the datasetby state and calculate avg loan amount across states
final_dataset.groupby("State")["Loan Amount"].count().reset_index().sort_values("Loan Amount",ascending= False)
# Out:
#                         State  Loan Amount
# 21                MAHARASHTRA        10264
# 18                  KARNATAKA         8848
# 33                 TAMIL NADU         7198
# 34                  TELANGANA         6030
# 1              ANDHRA PRADESH         5459
# 36              UTTAR PRADESH         5310
# 11                    GUJARAT         4258
# 31                  RAJASTHAN         3309
# 20             MADHYA PRADESH         2800
# 10                      DELHI         2794
# 38                WEST BENGAL         2303
# 13                    HARYANA         2118
# 4                       BIHAR         1968
# 28                     ODISHA         1812
# 19                     KERALA         1541
# 29                     PUNJAB         1124
# 2                       ASSAM          760
# 5                 CHATTISGARH          640
# 17                  JHARKHAND          630
# 37                UTTARAKHAND          330
# 14           HIMACHAL PRADESH          212
# 16            JAMMU & KASHMIR          196
# 30                Pondicherry          173
# 6                  Chandigarh          111
# 35                    TRIPURA           93
# 12                        Goa           60
# 24                    Manipur           54
# 25                  Meghalaya           35
# 9                 DAMAN & DIU           34
# 32                     Sikkim           29
# 27                   Nagaland           26
# 23                Maharashtra           21
# 15                    Haryana           15
# 3           Arunachal Pradesh           13
# 7                 Chattisgarh            8
# 8        DADRA & NAGAR HAVELI            5
# 26                    Mizoram            4
# 0   ANDAMAN & NICOBAR ISLANDS            4
# 22             Madhya Pradesh            2

# %% [markdown]
# **Himachal pradesh have the highest Loan amount average and Andaman &Nicobar islands have the lowest Loan amount sanctioned across the city**

# %% [markdown]
# #### Distribution of loans across different amounts

# %%
# Divide the data into categories
bins =  [1000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 15000]
# Use the `cut` function to assign each data point to a category
categories = pd.cut(final_dataset["Loan Amount"], bins, labels=["1000-5000", "5000-6000","6000-7000","7000-8000","8000-9000","9000-10000", "10000-11000","11000-15000"])

# Count the number of data points in each category
counts = categories.value_counts().reset_index().rename(columns={'Loan Amount': 'Count'})

# %%
counts
# Out:
#          index  Count
# 0    1000-5000  32231
# 1    6000-7000  14882
# 2    5000-6000  10170
# 3   9000-10000   3198
# 4  11000-15000   2394
# 5    7000-8000   1656
# 6  10000-11000    791
# 7    8000-9000    303

# %% [markdown]
# #### Distribution of customers by age

# %%
#select only those rows where the DOB is not null
dob_dataframe = final_dataset[final_dataset["DOB"].notnull()]

# %%
# convert to time stamp 
dob_dataframe["DOB"]= pd.to_datetime(dob_dataframe["DOB"],format='%Y-%m-%d %H:%M:%S')

# %%
today = datetime.now()#present day
dob_dataframe["Age"] = (today-dob_dataframe["DOB"]).astype('<m8[Y]')

# %%
age_distribution = dob_dataframe.groupby("Age")["Loan Amount"].mean().reset_index().sort_values("Age",ascending= True)

# %% [markdown]
# **Divide the age into four categories and see the loan amount distribution in thes categories**

# %%
# define the age_category function
def age_category(dataframe):
    if dataframe["Age"] >= 18 and dataframe["Age"] <=24 :
        dataframe["people Age section"] = "people Early 20s"
    elif dataframe["Age"] >=25 and dataframe["Age"] <=30 :
        dataframe["people Age section"] = "people in Mid 20s"
    elif dataframe["Age"] >=31 and dataframe["Age"] <=40 :
        dataframe["people Age section"] = "people in 30s"
    elif dataframe["Age"] >=41 and dataframe["Age"] <=50 :
        dataframe["people Age section"] = "people in 40s"
    elif dataframe["Age"] >=51 and dataframe["Age"] <=60 :
        dataframe["people Age section"] = "people in 50s"
    elif dataframe["Age"] >=61 and dataframe["Age"] <=70 :
        dataframe["people Age section"] = "people in 60s"
    elif dataframe["Age"] >=71 and dataframe["Age"] <=80 :
        dataframe["people Age section"] = "people in 70s"
    return dataframe

# %%
age_dataset = dob_dataframe.apply(age_category, axis=1)

# %%
age_dataset.groupby("people Age section")["Loan Amount"].mean().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#   people Age section  Loan Amount
# 4      people in 60s  5021.213333
# 5      people in 70s  5043.105263
# 0   people Early 20s  6598.527873
# 3      people in 50s  6724.163912
# 6  people in Mid 20s  7745.115521
# 2      people in 40s  7841.033528
# 1      people in 30s  8052.390373

# %%
age_dataset.groupby("people Age section")["Loan Amount"].count().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#   people Age section  Loan Amount
# 5      people in 70s           19
# 4      people in 60s           75
# 3      people in 50s          726
# 2      people in 40s         4271
# 1      people in 30s        18303
# 0   people Early 20s        20414
# 6  people in Mid 20s        26783

# %% [markdown]
# **People in their 3o have the highest loan amount Distribution followed by people in 40s However people in their 60s have lowest Loan amount distribution followed by people in 70s and people in early 20s**

# %% [markdown]
# #### Distribution of loans by due dates

# %%
age_dataset.groupby("Due Date")["Loan Amount"].mean().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#      Due Date    Loan Amount
# 14 2022-11-14    6115.435286
# 21 2022-11-21    6472.757015
# 15 2022-11-15    6490.685978
# 19 2022-11-19    6753.528858
# 20 2022-11-20    6765.244860
# 25 2022-11-25    6782.857967
# 12 2022-11-12    6905.481984
# 13 2022-11-13    6965.586239
# 5  2022-11-05    7330.517038
# 2  2022-11-02    7367.940163
# 6  2022-11-06    7401.303701
# 8  2022-11-08    7434.464968
# 7  2022-11-07    7686.543129
# 1  2022-11-01    7816.673625
# 18 2022-11-18    7828.538913
# 17 2022-11-17    7876.599262
# 10 2022-11-10    7916.286360
# 4  2022-11-04    7931.927431
# 22 2022-11-22    7960.516511
# 16 2022-11-16    7991.469302
# 11 2022-11-11    7991.817808
# 9  2022-11-09    8010.115604
# 3  2022-11-03    8210.676092
# 23 2022-11-23    8352.628610
# 24 2022-11-24    9288.734899
# 26 2022-11-26   14209.167059
# 29 2022-11-29   18513.828571
# 28 2022-11-28   24486.532258
# 27 2022-11-27   29754.891566
# 0  2022-10-31  240000.000000

# %%
# create a new column containing the day component of the datetime column
age_dataset['Due_date_day'] = age_dataset['Due Date'].dt.day

# %%
def week_of_month(dataframe):
    if dataframe['Due_date_day'] >=1 and dataframe['Due_date_day'] <=7 :
        dataframe['week']= "1st week of month"
    elif dataframe['Due_date_day'] >=8 and dataframe['Due_date_day'] <=14 :
        dataframe['week']= "2nd week of month"
    elif dataframe['Due_date_day'] >=15 and dataframe['Due_date_day'] <=22 :
        dataframe['week']= "3rd week of month"
    elif dataframe['Due_date_day'] >=23 and dataframe['Due_date_day'] <=31 :
        dataframe['week']= "4th week of month"
        
    return dataframe

# %%
week_month_dataset = age_dataset.apply(week_of_month, axis=1)

# %%
week_month_dataset.groupby("week")["Loan Amount"].mean().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#                 week  Loan Amount
# 2  3rd week of month  7142.345338
# 1  2nd week of month  7264.346843
# 0  1st week of month  7670.235630
# 3  4th week of month  8284.446340

# %%
week_month_dataset.groupby("week")["Loan Amount"].count().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#                 week  Loan Amount
# 3  4th week of month         9016
# 1  2nd week of month        16013
# 0  1st week of month        22599
# 2  3rd week of month        22963

# %% [markdown]
# #### Unique number of customers contacted every day - only completed calls are to be considered - How many unique borrowers did we contact on day 1, day 2 etc.

# %%
#select only those rows were status is completed 
unique_number_dataset = final_dataset[final_dataset["Status"] =="completed"]

# %%
#separate unique days 
unique_number_dataset["Call time day"] = unique_number_dataset["Call time"].dt.day

# %%
#group the Loan Number with days
Unique_number_customers_contacted = unique_number_dataset.groupby('Call time day')["Loan Number"].nunique().reset_index().rename(columns={'Loan Number': 'unique custumers'})

# %% [markdown]
# #### Number of customers not contacted on every day. How many borrowers are not contacted on day 1, day 2 etc

# %%
Unique_customers_contacted = unique_number_dataset.groupby('Call time day')["Loan Number"].unique().reset_index().rename(columns={'Loan Number': 'unique custumers'})

# %%
# define a function to get the set of not contacted customers for a given row
def get_not_contacted(row):
    return (list(set(final_dataset["Loan Number"]) - set(row)))

# %%
# apply the function to each row of the 'unique custumers' column
Unique_customers_contacted["not contacted"] = Unique_customers_contacted["unique custumers"].apply(get_not_contacted)

# %%
Unique_customers_contacted["not contacted len"] = Unique_customers_contacted["not contacted"].apply(lambda x: len(x))

# %% [markdown]
# #### Who are the customers who have been contacted the most

# %%
# group by Call time Status and count unique Loan Numbers
loan_count_by_status = unique_number_dataset.groupby("Loan Number")["Call time"].nunique().reset_index().rename(columns={'Call time': 'no of times contacted'}).sort_values("no of times contacted",ascending=False)

# %%
loan_count_by_status
# Out:
#        Loan Number  no of times contacted
# 3390       1659081                     38
# 1747       1580447                     30
# 1428       1564892                     28
# 1146       1542440                     28
# 7433       1759399                     27
# ...            ...                    ...
# 4275       1682574                      1
# 4264       1682370                      1
# 9013       1790863                      1
# 4259       1682156                      1
# 11216  16748071234                      1
#
# [11217 rows x 2 columns]

# %% [markdown]
# #### Who are the customers who have been contacted the least

# %%
loan_count_by_status.sort_values("no of times contacted",ascending=True)
# Out:
#        Loan Number  no of times contacted
# 11216  16748071234                      1
# 5923       1723337                      1
# 5922       1723323                      1
# 5916       1723178                      1
# 5912       1723095                      1
# ...            ...                    ...
# 7433       1759399                     27
# 1146       1542440                     28
# 1428       1564892                     28
# 1747       1580447                     30
# 3390       1659081                     38
#
# [11217 rows x 2 columns]

# %% [markdown]
# #### How many customers have never been reached out?

# %%
customer_not_connected = final_dataset[final_dataset["Status"] !="completed"]

# %%
customer_not_connected.groupby("Loan Number")["Call time"].nunique().reset_index().sort_values("Call time",ascending=False)
# Out:
#     Loan Number  Call time
# 0       1449973          1
# 1       1519456          1
# 16      1804073          1
# 15      1796386          1
# 14      1794528          1
# 13      1793754          1
# 12      1786023          1
# 11      1718725          1
# 10      1698688          1
# 9       1684603          1
# 8       1683330          1
# 7       1677999          1
# 6       1626272          1
# 5       1599712          1
# 4       1581587          1
# 3       1580879          1
# 2       1565907          1
# 17      1813406          1

# %%
customer_not_connected
# Out:
#        Loan Number  Campaign ID Communication Operator Message ID  \
# 28395      1449973    167104481          326c646a6364353337303435
# 28675      1599712    167104481          326c646a6e68393633383931
# 29084      1677999    167104481          326c646a7667343336303731
# 29196      1718725    167104481          326c646a426b303534373130
# 29882      1796386    167104481          326c646a5161343032313039
# 45334      1565907    169508129          326c656e7867323131363235
# 45361      1581587    169508129          326c656e796a303734353237
# 45416      1626272    169508129          326c656e4134313134343136
# 45599      1683330    169508129          326c656e4930363830353337
# 45603      1684603    169508129          326c656e4963393638333538
# 45724      1698688    169508129          326c656e4b32303237373538
# 46287      1786023    169508129          326c656e3274353834373831
# 46396      1793754    169508129          326c656e3470383837343934
# 46398      1794528    169508129          326c656e3471313731383433
# 46572      1804073    169508129          326c656f306e323334313336
# 46603      1813406    169508129          326c656f6269333936383439
# 63877      1519456    172503474          326c676a6a66313634353238
# 63966      1580879    172503474          326c676a7130333838373535
#
#                              Call time  Status   Due Date           State  \
# 28395 2022-12-04 07:03:48.583000+00:00  FAILED 2022-11-01       TELANGANA
# 28675 2022-12-04 08:41:27.604000+00:00  FAILED 2022-11-02     WEST BENGAL
# 29084 2022-12-04 07:28:52.109000+00:00  FAILED 2022-11-20           DELHI
# 29196 2022-12-04 06:35:31.998000+00:00  FAILED 2022-11-05     MAHARASHTRA
# 29882 2022-12-04 07:23:24.997000+00:00  FAILED 2022-11-18       RAJASTHAN
# 45334 2022-12-05 16:16:54.745000+00:00  FAILED 2022-11-01      TAMIL NADU
# 45361 2022-12-05 09:55:21.749000+00:00  FAILED 2022-11-05     MAHARASHTRA
# 45416 2022-12-05 09:58:23.137000+00:00  FAILED 2022-11-07       TELANGANA
# 45599 2022-12-05 10:06:38.407000+00:00  FAILED 2022-11-21     MAHARASHTRA
# 45603 2022-12-05 10:06:39.984000+00:00  FAILED 2022-11-22     MAHARASHTRA
# 45724 2022-12-05 13:06:07.643000+00:00  FAILED 2022-11-25  MADHYA PRADESH
# 46287 2022-12-05 11:13:33.937000+00:00  FAILED 2022-11-16           DELHI
# 46396 2022-12-05 13:02:20.024000+00:00  FAILED 2022-11-18       KARNATAKA
# 46398 2022-12-05 12:34:42.815000+00:00  FAILED 2022-11-18           DELHI
# 46572 2022-12-05 10:30:44.496000+00:00  FAILED 2022-11-20  MADHYA PRADESH
# 46603 2022-12-05 13:22:12.466000+00:00  FAILED 2022-11-22     MAHARASHTRA
# 63877 2022-12-07 07:32:58.105000+00:00  FAILED 2022-11-13   UTTAR PRADESH
# 63966 2022-12-07 12:03:01.300000+00:00  FAILED 2022-11-05           DELHI
#
#                        DOB  Loan Amount
# 28395  1996-07-10 00:00:00      15060.0
# 28675  1996-06-15 00:00:00       7000.0
# 29084  2001-07-03 00:00:00       5000.0
# 29196  1988-08-25 00:00:00       5017.0
# 29882  1988-01-01 00:00:00       7000.0
# 45334  1991-09-07 00:00:00       5020.0
# 45361  1992-05-05 00:00:00       5020.0
# 45416  2000-04-07 00:00:00      10000.0
# 45599  2003-05-31 00:00:00       7000.0
# 45603  1994-02-21 00:00:00       5000.0
# 45724  1994-06-06 00:00:00       6000.0
# 46287  1992-10-28 00:00:00       5000.0
# 46396  1999-05-05 00:00:00       5000.0
# 46398  1994-05-14 00:00:00       5000.0
# 46572  1971-07-05 00:00:00       5000.0
# 46603  1985-09-20 00:00:00       5000.0
# 63877  1990-11-20 00:00:00      15000.0
# 63966  2001-04-06 00:00:00       7028.0

# %% [markdown]
# #### Distribution of calls by states.

# %%
#create final dataset by merging the two dataframe on  Loan Number column 
final_dataset = pd.merge(CommunicationHistory_df,portfolio_df,how='inner', on='Loan Number')

# %%
final_dataset["day"] = final_dataset["Call time"].dt.day

# %%
final_dataset.groupby("State")['day'].max().reset_index()
# Out:
#                         State  day
# 0   ANDAMAN & NICOBAR ISLANDS    4
# 1              ANDHRA PRADESH    7
# 2                       ASSAM    7
# 3           Arunachal Pradesh    7
# 4                       BIHAR    7
# 5                 CHATTISGARH    7
# 6                  Chandigarh    7
# 7                 Chattisgarh    5
# 8        DADRA & NAGAR HAVELI    7
# 9                 DAMAN & DIU    7
# 10                      DELHI    7
# 11                    GUJARAT    7
# 12                        Goa    7
# 13                    HARYANA    7
# 14           HIMACHAL PRADESH    7
# 15                    Haryana    7
# 16            JAMMU & KASHMIR    7
# 17                  JHARKHAND    7
# 18                  KARNATAKA    7
# 19                     KERALA    7
# 20             MADHYA PRADESH    7
# 21                MAHARASHTRA    7
# 22             Madhya Pradesh    2
# 23                Maharashtra    7
# 24                    Manipur    7
# 25                  Meghalaya    7
# 26                    Mizoram    4
# 27                   Nagaland    7
# 28                     ODISHA    7
# 29                     PUNJAB    7
# 30                Pondicherry    7
# 31                  RAJASTHAN    7
# 32                     Sikkim    7
# 33                 TAMIL NADU    7
# 34                  TELANGANA    7
# 35                    TRIPURA    7
# 36              UTTAR PRADESH    7
# 37                UTTARAKHAND    7
# 38                WEST BENGAL    7

# %%
final_dataset.groupby("State")['day'].count().reset_index()
# Out:
#                         State    day
# 0   ANDAMAN & NICOBAR ISLANDS      4
# 1              ANDHRA PRADESH   5459
# 2                       ASSAM    760
# 3           Arunachal Pradesh     13
# 4                       BIHAR   1968
# 5                 CHATTISGARH    640
# 6                  Chandigarh    111
# 7                 Chattisgarh      8
# 8        DADRA & NAGAR HAVELI      5
# 9                 DAMAN & DIU     34
# 10                      DELHI   2794
# 11                    GUJARAT   4258
# 12                        Goa     60
# 13                    HARYANA   2118
# 14           HIMACHAL PRADESH    212
# 15                    Haryana     15
# 16            JAMMU & KASHMIR    196
# 17                  JHARKHAND    630
# 18                  KARNATAKA   8848
# 19                     KERALA   1541
# 20             MADHYA PRADESH   2800
# 21                MAHARASHTRA  10264
# 22             Madhya Pradesh      2
# 23                Maharashtra     21
# 24                    Manipur     54
# 25                  Meghalaya     35
# 26                    Mizoram      4
# 27                   Nagaland     26
# 28                     ODISHA   1812
# 29                     PUNJAB   1124
# 30                Pondicherry    173
# 31                  RAJASTHAN   3309
# 32                     Sikkim     29
# 33                 TAMIL NADU   7198
# 34                  TELANGANA   6030
# 35                    TRIPURA     93
# 36              UTTAR PRADESH   5310
# 37                UTTARAKHAND    330
# 38                WEST BENGAL   2303

# %% [markdown]
#   #### Distribution of calls by campaign ids

# %%
final_dataset.groupby("Campaign ID")['day'].count().reset_index()
# Out:
#     Campaign ID   day
# 0     164168595  6905
# 1     164661895  6413
# 2     165448976  1684
# 3     165448984  3736
# 4     166203285  1507
# 5     166203288  3391
# 6     166790104  3286
# 7     166790108  1467
# 8     167104481     5
# 9     167104482  3416
# 10    167104488  1068
# 11    167820915   797
# 12    167820924  2692
# 13    168389540  3106
# 14    168389543   945
# 15    168801291  3545
# 16    168801293   878
# 17    169508122   660
# 18    169508126  3014
# 19    169508129    11
# 20    170181308  3637
# 21    170181312   694
# 22    170740199  3279
# 23    170740200   554
# 24    171446611   501
# 25    171446618  3045
# 26    172117487  2973
# 27    172117491   495
# 28    172503470  1183
# 29    172503471   486
# 30    172503474     2
# 31    172948097   316
# 32    172948100  2802
# 33    173536581  1632
# 34    173536583   466

# %%
final_dataset.groupby("Campaign ID")['day'].max().reset_index()
# Out:
#     Campaign ID  day
# 0     164168595    2
# 1     164661895    4
# 2     165448976    3
# 3     165448984    4
# 4     166203285    3
# 5     166203288    4
# 6     166790104    4
# 7     166790108    4
# 8     167104481    4
# 9     167104482    4
# 10    167104488    4
# 11    167820915    4
# 12    167820924    4
# 13    168389540    5
# 14    168389543    5
# 15    168801291    7
# 16    168801293    5
# 17    169508122    5
# 18    169508126    5
# 19    169508129    5
# 20    170181308    6
# 21    170181312    6
# 22    170740199    6
# 23    170740200    6
# 24    171446611    6
# 25    171446618    7
# 26    172117487    7
# 27    172117491    7
# 28    172503470    7
# 29    172503471    7
# 30    172503474    7
# 31    172948097    7
# 32    172948100    7
# 33    173536581    7
# 34    173536583    7

# %% [markdown]
# #### Unique number of customers by campaign ID

# %%
final_dataset.groupby("Campaign ID")['Loan Number'].nunique().reset_index()
# Out:
#     Campaign ID  Loan Number
# 0     164168595         6306
# 1     164661895         5833
# 2     165448976         1576
# 3     165448984         3430
# 4     166203285         1450
# 5     166203288         3189
# 6     166790104         3070
# 7     166790108         1408
# 8     167104481            5
# 9     167104482         3227
# 10    167104488         1019
# 11    167820915          747
# 12    167820924         2578
# 13    168389540         2925
# 14    168389543          877
# 15    168801291         3353
# 16    168801293          841
# 17    169508122          629
# 18    169508126         2878
# 19    169508129           11
# 20    170181308         3419
# 21    170181312          654
# 22    170740199         3127
# 23    170740200          529
# 24    171446611          472
# 25    171446618         2902
# 26    172117487         2789
# 27    172117491          463
# 28    172503470         1133
# 29    172503471          465
# 30    172503474            2
# 31    172948097          308
# 32    172948100         2663
# 33    173536581         1572
# 34    173536583          433

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Distribution of loans across different states

# %%
# Group by state and calculate the mean loan amount
state_loan_means = final_dataset.groupby("State")["Loan Amount"].mean().reset_index()

# Set the style to "whitegrid"
sns.set_style("whitegrid")

# Sort by mean loan amount in descending order
state_loan_means = state_loan_means.sort_values("Loan Amount", ascending=False)

# Create the horizontal bar plot with a larger figure size
fig, ax = plt.subplots(figsize=(20, 10))
# Create the horizontal bar plot
ax.barh(state_loan_means["State"], state_loan_means["Loan Amount"])
ax.set_xlabel("Mean Loan Amount")
ax.set_ylabel("State")
ax.set_title("Mean Loan Amount by State")
# Save the plot to a file
plt.savefig('Distribution of loans across different states.png',dpi=300, bbox_inches='tight') 
plt.show()

# %% [markdown]
# #### Distribution of loans across different amounts

# %%
# Create the pie chart
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(112, 6))
ax.pie(counts["Count"], labels=counts["index"], autopct='%1.1f%%')
ax.set_title('Distribution of loan across different amount')
# Save the plot to a file
plt.savefig('Distribution of loans across different Amounts.png',dpi=300, bbox_inches='tight') 
plt.show()

# %% [markdown]
# #### Distribution of customers by age

# %%
# Create the distribution plot using seaborn
sns.displot(data=age_distribution, x="Loan Amount", kde=True)

# Add title and axis labels
plt.title("Distribution of Loan Amount by Age")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
# Save the plot to a file
plt.savefig('Distribution of loans across different Amounts.png',dpi=300, bbox_inches='tight') 
# Show the plot
plt.show()

# %%
# Group by "people Age section" and calculate the mean loan amount
age_loan_means = age_dataset.groupby("people Age section")["Loan Amount"].mean().reset_index()
# Sort by mean loan amount in ascending order
age_loan_means = age_loan_means.sort_values("Loan Amount", ascending=True)

# Create the bar plot
sns.barplot(x="Loan Amount", y="people Age section", data=age_loan_means)

# Set the x-axis label
plt.xlabel("Mean Loan Amount")

# Set the y-axis label
plt.ylabel("Age Section")
# Save the plot to a file
plt.savefig('Distribution of loans across different Ages.png',dpi=300, bbox_inches='tight') 
# Show the plot
plt.show()

# %%
# Group by "people Age section" and count the loans
age_loan_counts = age_dataset.groupby("people Age section")["Loan Amount"].count().reset_index()

# Sort by loan count in ascending order
age_loan_counts = age_loan_counts.sort_values("Loan Amount", ascending=True)
# Set the figure size to 8 inches by 6 inches
plt.figure(figsize=(15, 10))

# Create the pie chart
plt.pie(age_loan_counts["Loan Amount"], labels=age_loan_counts["people Age section"], autopct='%1.1f%%')
# Save the plot to a file
plt.savefig('Distribution of loans across different Ages using pie chart.png',dpi=300, bbox_inches='tight') 
# Add a title to the plot
plt.title("Loan Counts by Age Section")

# Show the plot
plt.show()

# %% [markdown]
# #### Distribution of loans by due dates

# %%
week_month_dataset.groupby("week")["Loan Amount"].count().reset_index().sort_values("Loan Amount",ascending= True)
# Out:
#                 week  Loan Amount
# 3  4th week of month         9016
# 1  2nd week of month        16013
# 0  1st week of month        22599
# 2  3rd week of month        22963

# %%
week_of_month = week_month_dataset.groupby("week")["Loan Amount"].count().reset_index().sort_values("Loan Amount",ascending= True)
week_of_month = week_of_month.sort_values("Loan Amount",ascending = True)
# Set the figure size to 8 inches by 6 inches
plt.figure(figsize=(15, 10))

# Create the pie chart
plt.pie(week_of_month["Loan Amount"], labels=week_of_month["week"], autopct='%1.1f%%')
# Save the plot to a file
plt.savefig('Distribution of loans by due date .png',dpi=300, bbox_inches='tight') 
# Add a title to the plot
plt.title("Distribution of loans by due date")

# Show the plot
plt.show()

# %%
# Create the bar plot
sns.barplot(x="week", y="Loan Amount", data=week_of_month)

# Set the x-axis label
plt.xlabel("week of the month ")

# Set the y-axis label
plt.ylabel("Loan amount ")
# Save the plot to a file
plt.savefig('Distribution of loans with due date barcart ',dpi=300, bbox_inches='tight') 
# Show the plot
plt.show()

# %% [markdown]
# #### Unique number of customers contacted every day - only completed calls are to be considered - How many unique borrowers did we contact on day 1, day 2 etc.

# %%
# create a dictionary to map the values of "Call time day" to the corresponding days of the week
day_map = {2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}
Unique_number_customers_contacted['Call time day of week'] = Unique_number_customers_contacted['Call time day'].map(day_map)


# create a bar plot using Seaborn
sns.barplot(x='Call time day of week', y='unique custumers', data=Unique_number_customers_contacted)

# set the title of the plot
plt.title('Number of Unique Customers Contacted by Day of the Week')
# Save the plot to a file
plt.savefig('Number of unique customers contacted in week.png',dpi=300, bbox_inches='tight')
# show the plot
plt.show()

# %% [markdown]
# #### Number of customers not contacted on every day. How many borrowers are not contacted on day 1, day 2 etc

# %%
Unique_customers_contacted
# Out:
#    Call time day                                   unique custumers  \
# 0              2  [16748071234, 16734601234, 1631580, 1553632, 1...
# 1              3  [1264634, 1800029, 1580495, 1644874, 1817609, ...
# 2              4  [1515117, 1708506, 1763956, 1618083, 1465243, ...
# 3              5  [1555261, 1771018, 1559893, 1723651, 1793657, ...
# 4              6  [1601443, 1719376, 1727291, 1817270, 1777466, ...
# 5              7  [1754097, 1808265, 1771018, 1696683, 1788930, ...
#
#                                        not contacted  not contacted len
# 0  [1687553, 1269761, 1720324, 1720325, 1712135, ...               3375
# 1  [1687553, 1671170, 1720324, 1720325, 1712135, ...               4291
# 2  [1671170, 1736710, 1638406, 1605644, 1736720, ...               5117
# 3  [1671170, 1736710, 1703964, 1671204, 1769514, ...               4936
# 4  [1769472, 1671170, 1802243, 1736710, 1638406, ...               5555
# 5  [1769472, 1802243, 1736710, 1638406, 1769496, ...               6959

# %%
Unique_customers_contacted['Call time day']=Unique_customers_contacted['Call time day'].map(day_map)
# create a bar plot using Seaborn
sns.barplot(x='Call time day', y='not contacted len', data=Unique_customers_contacted)

# set the title of the plot
plt.title('Number of Unique Customers Not Contacted by Day of the Week')
# Save the plot to a file
plt.savefig('Number of unique customers not  contacted in week.png',dpi=300, bbox_inches='tight')
# show the plot
plt.show()

# %% [markdown]
# #### Distribution of calls by states.

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

plt.figure(figsize=(12, 6))
sns.barplot(x="day", y="State", data=final_dataset.groupby("State")['day'].count().reset_index().sort_values('day'), color="royalblue")
plt.title("Number of Calls by State", fontsize=14)
plt.xlabel("Number of CallsState", fontsize=12)
plt.ylabel("State ", fontsize=12)
plt.show()

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

plt.figure(figsize=(12, 6))
sns.barplot(x="Campaign ID", y="day", data=final_dataset.groupby("Campaign ID")['day'].count().reset_index().sort_values('day',ascending = True), color="coral")
# rotate x-axis labels vertically
plt.xticks(rotation=90)
plt.title("Distribution of call by campaign id", fontsize=14)
plt.xlabel("Campaign ID", fontsize=12)
plt.ylabel("calls made by campaign id on a certain day ", fontsize=12)
plt.show()

# %%
final_dataset.groupby("Campaign ID")['Loan Number'].nunique().reset_index()
